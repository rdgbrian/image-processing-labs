# %%
import matplotlib.pyplot as plt
import numpy as np
from src.discrete_fourier_transform import discrete_fourier_transform, fourier_spectrum, create_white_square, rgb2gray

# %%
# Example: 10x10 image with a 4x4 white square in the center
n = 512
square_size = 16
image = create_white_square(n, square_size)

# image = plt.imread("Lab1-Inverting_Image/crying-cat-meme.jpg")
print(image.shape) # show the dimensions of the image
plt.imshow(image)
plt.show()
# Out:
# (512, 512)

# %%
f = np.fft.fft2(image)
f_centered = np.fft.fftshift(f)
real_f = f.real
imag_f = f.imag

np_fs_image = fourier_spectrum(real_f, imag_f)

f_centered = np.fft.fftshift(f)
real_f_centered = f_centered.real
imag_f_centered = f_centered.imag

np_centered_fs_image = fourier_spectrum(real_f_centered, imag_f_centered)

plt.imshow(np_fs_image)
plt.show()

plt.imshow(np_centered_fs_image)
plt.show()

# %%
from src.fast_fourier_transform import fast_fourier_transform

# %%
fast_fourier_transform(image)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fast_fourier_transform(image)
#
# File c:\Users\rdgbr\Documents\University-Stuff\Fall-2024\Digital Image Processing\image-processing-labs\src\fast_fourier_transform.py:220, in fast_fourier_transform(image, partition_str, save_info)
#     218 Fee, save_info_ee = fast_fourier_transform(image,partition_str=partition_str+"ee",save_info=save_info) # each should output matrix the size of 2 x N/2 x N/2 (2 at the end is for the real and imaginary part)
#     219 Feo, save_info_eo = fast_fourier_transform(image,partition_str=partition_str+"eo",save_info=save_info)
# --> 220 Foe, save_info_oe = fast_fourier_transform(image,partition_str=partition_str+"oe",save_info=save_info)
#     221 Foo, save_info_oo = fast_fourier_transform(image,partition_str=partition_str+"oo",save_info=save_info)
#     223 comb_save_info = None
#
# File c:\Users\rdgbr\Documents\University-Stuff\Fall-2024\Digital Image Processing\image-processing-labs\src\fast_fourier_transform.py:218, in fast_fourier_transform(image, partition_str, save_info)
#     215     return dft2x2, temp_info
#     217 # would store both the real and imaginary part
# --> 218 Fee, save_info_ee = fast_fourier_transform(image,partition_str=partition_str+"ee",save_info=save_info) # each should output matrix the size of 2 x N/2 x N/2 (2 at the end is for the real and imaginary part)
#     219 Feo, save_info_eo = fast_fourier_transform(image,partition_str=partition_str+"eo",save_info=save_info)
#     220 Foe, save_info_oe = fast_fourier_transform(image,partition_str=partition_str+"oe",save_info=save_info)
#
# File c:\Users\rdgbr\Documents\University-Stuff\Fall-2024\Digital Image Processing\image-processing-labs\src\fast_fourier_transform.py:237, in fast_fourier_transform(image, partition_str, save_info)
#     235 F[v,u+N//2]       = Fee[v,u] + mult_complex(Feo[v,u],weight(v,N)) - mult_complex(Foe[v,u],weight(u,N)) - mult_complex(Foo[v,u],weight(u+v,N)) # + +--
#     236 F[v+N//2,u]       = Fee[v,u] - mult_complex(Feo[v,u],weight(v,N)) + mult_complex(Foe[v,u],weight(u,N)) - mult_complex(Foo[v,u],weight(u+v,N)) # + -+-
# --> 237 F[v+N//2,u+N//2]  = Fee[v,u] - mult_complex(Feo[v,u],weight(v,N)) - mult_complex(Foe[v,u],weight(u,N)) + mult_complex(Foo[v,u],weight(u+v,N)) # + --+
#     239 if save_info:
#     240     dependents = [comb_save_info[partition_str+"ee"][v][u],
#     241                   comb_save_info[partition_str+"eo"][v][u],
#     242                   comb_save_info[partition_str+"oe"][v][u],
#     243                   comb_save_info[partition_str+"oo"][v][u] ]
#
# KeyboardInterrupt:

# %%
temp_fft, info = fast_fourier_transform(image)

temp_fft = temp_fft.transpose(2,0,1)
print(temp_fft.shape)
fft_real, fft_imaginary  = temp_fft

dft_fs_image = fourier_spectrum(fft_real, fft_imaginary)

plt.imshow(dft_fs_image)
plt.show()
# Out:
# (2, 512, 512)

# %%
from src.utils import center_fourier

cent_fft_real, cent_fft_imaginary = center_fourier(fft_real,fft_imaginary)

dft_fs_image = fourier_spectrum(cent_fft_real, cent_fft_imaginary)

plt.imshow(dft_fs_image)

# %%
temp_fft, info = fast_fourier_transform(image)

fft_real, fft_imaginary  = temp_fft

dft_fs_image = fourier_spectrum(fft_real, fft_imaginary)

plt.imshow(dft_fs_image)
plt.show()

# %% [markdown]
# ## Visualiztion

# %%
info['ee'][0][1].relative_cord
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 info['ee'][0][1].relative_cord
#
# TypeError: 'NoneType' object is not subscriptable

# %%
def see_partition(partition):
    if partition.dependants is None:
        return
    
    for dependant in partition.dependants:
        see_partition(dependant)
        if dependant.dependants is None:
            print("f" + str(partition.image_cord) + " | F" + partition.partition_string + str(partition.relative_cord))
        else:
            print("F" + partition.partition_string + str(partition.relative_cord))

# %%
def see_partition(partition):
    if partition.dependants is None:
        print("F" + partition.partition_string + str(partition.relative_cord) + "\tf" + str(partition.image_cord))
        return
    
    for dependant in partition.dependants:
        see_partition(dependant)
    print("F" + partition.partition_string + str(partition.relative_cord) +  f"\tW top={partition.weight_params_top} bottom={partition.weight_params_bottom}")

# %%
partition = info[''][1][0]


see_partition(partition)
# Out:
# Feeeeee(1, 0)	f[[[0, 0], [0, 8]], [[8, 0], [8, 8]]]
# Feeeeeo(1, 0)	f[[[4, 0], [4, 8]], [[12, 0], [12, 8]]]
# Feeeeoe(1, 0)	f[[[0, 4], [0, 12]], [[8, 4], [8, 12]]]
# Feeeeoo(1, 0)	f[[[4, 4], [4, 12]], [[12, 4], [12, 12]]]
# Feeee(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feeeoee(1, 0)	f[[[2, 0], [2, 8]], [[10, 0], [10, 8]]]
# Feeeoeo(1, 0)	f[[[6, 0], [6, 8]], [[14, 0], [14, 8]]]
# Feeeooe(1, 0)	f[[[2, 4], [2, 12]], [[10, 4], [10, 12]]]
# Feeeooo(1, 0)	f[[[6, 4], [6, 12]], [[14, 4], [14, 12]]]
# Feeeo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feeoeee(1, 0)	f[[[0, 2], [0, 10]], [[8, 2], [8, 10]]]
# Feeoeeo(1, 0)	f[[[4, 2], [4, 10]], [[12, 2], [12, 10]]]
# Feeoeoe(1, 0)	f[[[0, 6], [0, 14]], [[8, 6], [8, 14]]]
# Feeoeoo(1, 0)	f[[[4, 6], [4, 14]], [[12, 6], [12, 14]]]
# Feeoe(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feeooee(1, 0)	f[[[2, 2], [2, 10]], [[10, 2], [10, 10]]]
# Feeooeo(1, 0)	f[[[6, 2], [6, 10]], [[14, 2], [14, 10]]]
# Feeoooe(1, 0)	f[[[2, 6], [2, 14]], [[10, 6], [10, 14]]]
# Feeoooo(1, 0)	f[[[6, 6], [6, 14]], [[14, 6], [14, 14]]]
# Feeoo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Fee(1, 0)	W top=[0, 0, 1, 1] bottom=2.0
# Feoeeee(1, 0)	f[[[1, 0], [1, 8]], [[9, 0], [9, 8]]]
# Feoeeeo(1, 0)	f[[[5, 0], [5, 8]], [[13, 0], [13, 8]]]
# Feoeeoe(1, 0)	f[[[1, 4], [1, 12]], [[9, 4], [9, 12]]]
# Feoeeoo(1, 0)	f[[[5, 4], [5, 12]], [[13, 4], [13, 12]]]
# Feoee(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feoeoee(1, 0)	f[[[3, 0], [3, 8]], [[11, 0], [11, 8]]]
# Feoeoeo(1, 0)	f[[[7, 0], [7, 8]], [[15, 0], [15, 8]]]
# Feoeooe(1, 0)	f[[[3, 4], [3, 12]], [[11, 4], [11, 12]]]
# Feoeooo(1, 0)	f[[[7, 4], [7, 12]], [[15, 4], [15, 12]]]
# Feoeo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feooeee(1, 0)	f[[[1, 2], [1, 10]], [[9, 2], [9, 10]]]
# Feooeeo(1, 0)	f[[[5, 2], [5, 10]], [[13, 2], [13, 10]]]
# Feooeoe(1, 0)	f[[[1, 6], [1, 14]], [[9, 6], [9, 14]]]
# Feooeoo(1, 0)	f[[[5, 6], [5, 14]], [[13, 6], [13, 14]]]
# Feooe(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feoooee(1, 0)	f[[[3, 2], [3, 10]], [[11, 2], [11, 10]]]
# Feoooeo(1, 0)	f[[[7, 2], [7, 10]], [[15, 2], [15, 10]]]
# Feooooe(1, 0)	f[[[3, 6], [3, 14]], [[11, 6], [11, 14]]]
# Feooooo(1, 0)	f[[[7, 6], [7, 14]], [[15, 6], [15, 14]]]
# Feooo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Feo(1, 0)	W top=[0, 0, 1, 1] bottom=2.0
# Foeeeee(1, 0)	f[[[0, 1], [0, 9]], [[8, 1], [8, 9]]]
# Foeeeeo(1, 0)	f[[[4, 1], [4, 9]], [[12, 1], [12, 9]]]
# Foeeeoe(1, 0)	f[[[0, 5], [0, 13]], [[8, 5], [8, 13]]]
# Foeeeoo(1, 0)	f[[[4, 5], [4, 13]], [[12, 5], [12, 13]]]
# Foeee(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foeeoee(1, 0)	f[[[2, 1], [2, 9]], [[10, 1], [10, 9]]]
# Foeeoeo(1, 0)	f[[[6, 1], [6, 9]], [[14, 1], [14, 9]]]
# Foeeooe(1, 0)	f[[[2, 5], [2, 13]], [[10, 5], [10, 13]]]
# Foeeooo(1, 0)	f[[[6, 5], [6, 13]], [[14, 5], [14, 13]]]
# Foeeo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foeoeee(1, 0)	f[[[0, 3], [0, 11]], [[8, 3], [8, 11]]]
# Foeoeeo(1, 0)	f[[[4, 3], [4, 11]], [[12, 3], [12, 11]]]
# Foeoeoe(1, 0)	f[[[0, 7], [0, 15]], [[8, 7], [8, 15]]]
# Foeoeoo(1, 0)	f[[[4, 7], [4, 15]], [[12, 7], [12, 15]]]
# Foeoe(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foeooee(1, 0)	f[[[2, 3], [2, 11]], [[10, 3], [10, 11]]]
# Foeooeo(1, 0)	f[[[6, 3], [6, 11]], [[14, 3], [14, 11]]]
# Foeoooe(1, 0)	f[[[2, 7], [2, 15]], [[10, 7], [10, 15]]]
# Foeoooo(1, 0)	f[[[6, 7], [6, 15]], [[14, 7], [14, 15]]]
# Foeoo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foe(1, 0)	W top=[0, 0, 1, 1] bottom=2.0
# Fooeeee(1, 0)	f[[[1, 1], [1, 9]], [[9, 1], [9, 9]]]
# Fooeeeo(1, 0)	f[[[5, 1], [5, 9]], [[13, 1], [13, 9]]]
# Fooeeoe(1, 0)	f[[[1, 5], [1, 13]], [[9, 5], [9, 13]]]
# Fooeeoo(1, 0)	f[[[5, 5], [5, 13]], [[13, 5], [13, 13]]]
# Fooee(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Fooeoee(1, 0)	f[[[3, 1], [3, 9]], [[11, 1], [11, 9]]]
# Fooeoeo(1, 0)	f[[[7, 1], [7, 9]], [[15, 1], [15, 9]]]
# Fooeooe(1, 0)	f[[[3, 5], [3, 13]], [[11, 5], [11, 13]]]
# Fooeooo(1, 0)	f[[[7, 5], [7, 13]], [[15, 5], [15, 13]]]
# Fooeo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foooeee(1, 0)	f[[[1, 3], [1, 11]], [[9, 3], [9, 11]]]
# Foooeeo(1, 0)	f[[[5, 3], [5, 11]], [[13, 3], [13, 11]]]
# Foooeoe(1, 0)	f[[[1, 7], [1, 15]], [[9, 7], [9, 15]]]
# Foooeoo(1, 0)	f[[[5, 7], [5, 15]], [[13, 7], [13, 15]]]
# Foooe(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Fooooee(1, 0)	f[[[3, 3], [3, 11]], [[11, 3], [11, 11]]]
# Fooooeo(1, 0)	f[[[7, 3], [7, 11]], [[15, 3], [15, 11]]]
# Foooooe(1, 0)	f[[[3, 7], [3, 15]], [[11, 7], [11, 15]]]
# Foooooo(1, 0)	f[[[7, 7], [7, 15]], [[15, 7], [15, 15]]]
# Foooo(1, 0)	W top=[0, 0, 1, 1] bottom=4.0
# Foo(1, 0)	W top=[0, 0, 1, 1] bottom=2.0
# F(1, 0)	W top=[0, 0, 1, 1] bottom=1.0

# %%
print(info.partitions['eeee'])
# Out:
# [[<src.fast_fourier_transform.fft_partition object at 0x000001B7E82C3640>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6236C80>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E82C3A90>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6236AA0>], [<src.fast_fourier_transform.fft_partition object at 0x000001B7E6234700>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E62373D0>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6237FA0>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6234730>], [<src.fast_fourier_transform.fft_partition object at 0x000001B7E82C3670>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6236980>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E5FE77C0>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6235FC0>], [<src.fast_fourier_transform.fft_partition object at 0x000001B7E6236110>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6234790>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6237F70>, <src.fast_fourier_transform.fft_partition object at 0x000001B7E6234760>]]

# %% [markdown]
# ## Sanity Check

# %%
# are_equal = np.allclose(dft_fs_image, np_fs_image, rtol=1e-6, atol=1e-9)

# print("Are the arrays equal to the given precision?", are_equal)
are_equal = np.allclose(fft_imaginary, imag_f, rtol=1e-6, atol=1e-9)

print("Are the arrays equal to the given precision?", are_equal)
are_equal = np.allclose(fft_real, real_f, rtol=1e-6, atol=1e-9)

print("Are the arrays equal to the given precision?", are_equal)
# Out:
# Are the arrays equal to the given precision? True
# Are the arrays equal to the given precision? True
